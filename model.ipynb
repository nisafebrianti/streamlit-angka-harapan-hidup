# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('Life_Expectancy_Data.csv')
pd.set_option('display.max_columns', None)

# %% [markdown]
# link dataset
# https://www.kaggle.com/datasets/uom190346a/health-and-demographics-dataset/data

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0              263
# 1  Afghanistan  2014  Developing              59.9              271
# 2  Afghanistan  2013  Developing              59.9              268
# 3  Afghanistan  2012  Developing              59.5              272
# 4  Afghanistan  2011  Developing              59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624           65      1154
# 1             64     0.01               73.523582           62       492
# 2             66     0.01               73.219243           64       430
# 3             69     0.01               78.184215           67      2787
# 4             71     0.01                7.097109           68      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0   19.1                  83      6               8.16           65
# 1   18.6                  86     58               8.18           62
# 2   18.1                  89     62               8.13           64
# 3   17.6                  93     67               8.52           67
# 4   17.2                  97     68               7.87           68
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                 17.5                            0.476       10.0
# 2                 17.7                            0.470        9.9
# 3                 18.0                            0.463        9.8
# 4                 18.2                            0.454        9.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   object
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   int64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   int64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
#  12  Polio                            1649 non-null   int64
#  13  Total expenditure                1649 non-null   float64
#  14  Diphtheria                       1649 non-null   int64
#  15   HIV/AIDS                        1649 non-null   float64
#  16  GDP                              1649 non-null   float64
#  17  Population                       1649 non-null   float64
#  18   thinness  1-19 years            1649 non-null   float64
#  19   thinness 5-9 years              1649 non-null   float64
#  20  Income composition of resources  1649 non-null   float64
#  21  Schooling                        1649 non-null   float64
# dtypes: float64(12), int64(8), object(2)
# memory usage: 283.5+ KB

# %%
df.isna().sum()
# Out:
# Country                            0
# Year                               0
# Status                             0
# Life expectancy                    0
# Adult Mortality                    0
# infant deaths                      0
# Alcohol                            0
# percentage expenditure             0
# Hepatitis B                        0
# Measles                            0
#  BMI                               0
# under-five deaths                  0
# Polio                              0
# Total expenditure                  0
# Diphtheria                         0
#  HIV/AIDS                          0
# GDP                                0
# Population                         0
#  thinness  1-19 years              0
#  thinness 5-9 years                0
# Income composition of resources    0
# Schooling                          0
# dtype: int64

# %%
plt.figure(figsize=(10,8))
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\bmkus\AppData\Local\Temp\ipykernel_12308\2675538813.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
df.head()
# Out:
#        Country  Year      Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015  Developing              65.0              263
# 1  Afghanistan  2014  Developing              59.9              271
# 2  Afghanistan  2013  Developing              59.9              268
# 3  Afghanistan  2012  Developing              59.5              272
# 4  Afghanistan  2011  Developing              59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624           65      1154
# 1             64     0.01               73.523582           62       492
# 2             66     0.01               73.219243           64       430
# 3             69     0.01               78.184215           67      2787
# 4             71     0.01                7.097109           68      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0   19.1                  83      6               8.16           65
# 1   18.6                  86     58               8.18           62
# 2   18.1                  89     62               8.13           64
# 3   17.6                  93     67               8.52           67
# 4   17.2                  97     68               7.87           68
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                 17.5                            0.476       10.0
# 2                 17.7                            0.470        9.9
# 3                 18.0                            0.463        9.8
# 4                 18.2                            0.454        9.5

# %%
def isfloat(num):
    try:
        float(num)
        return True
    except ValueError:
        return False

# %%
y = [x for x in df['Status'] if isfloat(x) == False]
print(y)
# Out:
# ['Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developed', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing', 'Developing' ...

# %%
df['Status']=df['Status'].replace(['Developing','Developed'],['0','1'])
df[['Status']]=df[['Status']].apply(pd.to_numeric)

# %%
df.head()
# Out:
#        Country  Year  Status  Life expectancy   Adult Mortality  \
# 0  Afghanistan  2015       0              65.0              263
# 1  Afghanistan  2014       0              59.9              271
# 2  Afghanistan  2013       0              59.9              268
# 3  Afghanistan  2012       0              59.5              272
# 4  Afghanistan  2011       0              59.2              275
#
#    infant deaths  Alcohol  percentage expenditure  Hepatitis B  Measles   \
# 0             62     0.01               71.279624           65      1154
# 1             64     0.01               73.523582           62       492
# 2             66     0.01               73.219243           64       430
# 3             69     0.01               78.184215           67      2787
# 4             71     0.01                7.097109           68      3013
#
#     BMI   under-five deaths   Polio  Total expenditure  Diphtheria   \
# 0   19.1                  83      6               8.16           65
# 1   18.6                  86     58               8.18           62
# 2   18.1                  89     62               8.13           64
# 3   17.6                  93     67               8.52           67
# 4   17.2                  97     68               7.87           68
#
#     HIV/AIDS         GDP  Population   thinness  1-19 years  \
# 0        0.1  584.259210  33736494.0                   17.2
# 1        0.1  612.696514    327582.0                   17.5
# 2        0.1  631.744976  31731688.0                   17.7
# 3        0.1  669.959000   3696958.0                   17.9
# 4        0.1   63.537231   2978599.0                   18.2
#
#     thinness 5-9 years  Income composition of resources  Schooling
# 0                 17.3                            0.479       10.1
# 1                 17.5                            0.476       10.0
# 2                 17.7                            0.470        9.9
# 3                 18.0                            0.463        9.8
# 4                 18.2                            0.454        9.5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1649 entries, 0 to 1648
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          1649 non-null   object
#  1   Year                             1649 non-null   int64
#  2   Status                           1649 non-null   int64
#  3   Life expectancy                  1649 non-null   float64
#  4   Adult Mortality                  1649 non-null   int64
#  5   infant deaths                    1649 non-null   int64
#  6   Alcohol                          1649 non-null   float64
#  7   percentage expenditure           1649 non-null   float64
#  8   Hepatitis B                      1649 non-null   int64
#  9   Measles                          1649 non-null   int64
#  10   BMI                             1649 non-null   float64
#  11  under-five deaths                1649 non-null   int64
#  12  Polio                            1649 non-null   int64
#  13  Total expenditure                1649 non-null   float64
#  14  Diphtheria                       1649 non-null   int64
#  15   HIV/AIDS                        1649 non-null   float64
#  16  GDP                              1649 non-null   float64
#  17  Population                       1649 non-null   float64
#  18   thinness  1-19 years            1649 non-null   float64
#  19   thinness 5-9 years              1649 non-null   float64
#  20  Income composition of resources  1649 non-null   float64
#  21  Schooling                        1649 non-null   float64
# dtypes: float64(12), int64(9), object(1)
# memory usage: 283.5+ KB

# %%
df.rename(columns = {"Schooling":"schooling","Income composition of resources":"icr","percentage expenditure":"pe"},inplace=True)

# %%
df.rename(columns = {" BMI ":"bmi","Diphtheria ":"diphtheria","Life expectancy ":"life_expectancy","GDP":"gdp"},inplace=True)

# %% [markdown]
# dari data diatas, nilai dengan korelasi tertinggi adalah schooling, income, gdp, diphtheria, bmi, percentage, alcohol, status

# %%
features = ['schooling','icr','gdp','diphtheria','bmi','pe','Alcohol','Status']
x = df[features]
y = df['life_expectancy']
x.shape, y.shape
# Out:
# ((1649, 8), (1649,))

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y,random_state=34,test_size=0.1)
y_test.shape
x_train.shape
# Out:
# (1484, 8)

# %%
x_test.shape
# Out:
# (165, 8)

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error

pl = make_pipeline(PolynomialFeatures(degree=2) , Ridge())
pl.fit(x_train , y_train)
y_pred_poly = pl.predict(x_test)
# Out:
# c:\Users\bmkus\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.27801e-22): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
score = pl.score(x_test,y_test)
print('Akurasi model PolynomialFeatures', score)
# Out:
# Akurasi model PolynomialFeatures 0.7675675344547164

# %%
input_data = np.array([[9.5,0.454,63.537231,68,17.2,7.097109,0.01,0]])

prediction = pl.predict(input_data)
print('Estimasi Angka Harapan Hidup :',prediction)
print('Angka Harapan Hidup Asli adalh : 59.5')
# Out:
# Estimasi Angka Harapan Hidup : [60.02933821]
# Angka Harapan Hidup Asli adalh : 59.5
# c:\Users\bmkus\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
input_data = np.array([[10.1,0.479,584.259210,65,19.1,71.279624,0.01,0]])

prediction = pl.predict(input_data)
print('Estimasi Angka Harapan Hidup :',prediction)
print('Angka Harapan Hidup Asli adalh : 65')
# Out:
# Estimasi Angka Harapan Hidup : [60.79081089]
# Angka Harapan Hidup Asli adalh : 65
# c:\Users\bmkus\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but PolynomialFeatures was fitted with feature names
#   warnings.warn(

# %%
from sklearn.metrics import r2_score

print('R2:', r2_score(y_test, y_pred_poly))
# Out:
# R2: 0.7675675344547164

# %%
import pickle

filename = 'estimasi_angka_harapan_hidup.sav'
pickle.dump(pl,open(filename,'wb'))
